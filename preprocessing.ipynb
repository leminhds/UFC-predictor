# %%
import numpy as np
import pandas as pd
import re
from datetime import datetime

# %%
df_fighters = pd.read_csv('fighters.csv')
df_cards = pd.read_csv('fightcards.csv')

# %% [markdown]
# ## Initial Exploration

# %%
df_fighters.head()
# Out:
#            DoB  SApM  SLpM height                name  reach   record  \
# 0  Jun 15 1989  6.11  1.11  6' 0"      Justin Frazier   75.0   10-3-0
# 1  Feb 07 1989  8.28  2.99  5' 9"      Gleidson Cutis    NaN    7-4-0
# 2  Jul 03 1982  2.50  1.47  6' 1"  Xavier Foupa-Pokam    NaN  32-22-0
# 3           --  3.29  0.71  6' 6"       Chuck Grigsby    NaN  23-10-0
# 4           --  3.14  0.79  6' 0"       Jason Gilliam    NaN   14-9-0
#
#         stance strAcc strDef  subAvg tdAcc  tdAvg tdDef weight
# 0     Southpaw    66%     4%     0.0    0%    0.0    0%    265
# 1     Orthodox    52%    59%     0.0    0%    0.0    0%    155
# 2  Open Stance    43%    49%     0.0    0%    0.0   16%    185
# 3     Orthodox    16%    46%     0.0    0%    0.0   66%    205
# 4     Orthodox    33%    42%     0.0    0%    0.0    0%    170

# %%
df_cards.head()
# Out:
#                               card_name                f1 f1_sig_strike_per  \
# 0  UFC Fight Night: Santos vs. Teixeira     Gustavo Lopez               60%
# 1       UFC Fight Night: Hall vs. Silva        Jason Witt               20%
# 2       UFC Fight Night: Hall vs. Silva     Dustin Jacoby               57%
# 3       UFC Fight Night: Hall vs. Silva       Miles Johns               45%
# 4         UFC 255: Figueiredo vs. Perez  Sasha Palatnikov               48%
#
#    f1_sig_strike_total  f1_td_attempt  f1_td_succeed               f2  \
# 0                   43              3              2  Anthony Birchak
# 1                    5              0              0    Cole Williams
# 2                   38              0              0     Justin Ledet
# 3                  105              7              0  Kevin Natividad
# 4                  206              9              1      Louis Cosce
#
#   f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  f2_td_succeed  \
# 0               42%                   40              0              0
# 1               64%                   31              3              2
# 2               32%                   31              0              0
# 3               24%                  137              1              0
# 4               52%                  237              1              1
#
#          fight_date         fights_location  round_format  round_fought  \
# 0  November 07 2020  Las Vegas, Nevada, USA             3             1
# 1   October 31 2020  Las Vegas, Nevada, USA             3             2
# 2   October 31 2020  Las Vegas, Nevada, USA             3             1
# 3   October 31 2020  Las Vegas, Nevada, USA             3             3
# 4  November 21 2020  Las Vegas, Nevada, USA             3             3
#
#         weight_class            winner winning_method
# 0       Bantamweight     Gustavo Lopez            SUB
# 1       Welterweight        Jason Witt            SUB
# 2  Light Heavyweight     Dustin Jacoby         KO/TKO
# 3       Bantamweight       Miles Johns         KO/TKO
# 4       Welterweight  Sasha Palatnikov         KO/TKO

# %%
df_fighters.dtypes
# Out:
# DoB        object
# SApM      float64
# SLpM      float64
# height     object
# name       object
# reach     float64
# record     object
# stance     object
# strAcc     object
# strDef     object
# subAvg    float64
# tdAcc      object
# tdAvg     float64
# tdDef      object
# weight     object
# dtype: object

# %%
df_cards.dtypes
# Out:
# card_name              object
# f1                     object
# f1_sig_strike_per      object
# f1_sig_strike_total     int64
# f1_td_attempt           int64
# f1_td_succeed           int64
# f2                     object
# f2_sig_strike_per      object
# f2_sig_strike_total     int64
# f2_td_attempt           int64
# f2_td_succeed           int64
# fight_date             object
# fights_location        object
# round_format            int64
# round_fought            int64
# weight_class           object
# winner                 object
# winning_method         object
# dtype: object

# %%
df_cards.isnull().sum()
# Out:
# card_name              0
# f1                     0
# f1_sig_strike_per      0
# f1_sig_strike_total    0
# f1_td_attempt          0
# f1_td_succeed          0
# f2                     0
# f2_sig_strike_per      0
# f2_sig_strike_total    0
# f2_td_attempt          0
# f2_td_succeed          0
# fight_date             0
# fights_location        0
# round_format           0
# round_fought           0
# weight_class           0
# winner                 0
# winning_method         0
# dtype: int64

# %%
df_fighters.isnull().sum()
# Out:
# DoB          0
# SApM         0
# SLpM         0
# height       0
# name         0
# reach     1982
# record       0
# stance     877
# strAcc       0
# strDef       0
# subAvg       0
# tdAcc        0
# tdAvg        0
# tdDef        0
# weight       0
# dtype: int64

# %%
print(df_fighters.apply(lambda col: col.nunique()))
# Out:
# DoB       2524
# SApM       758
# SLpM       650
# height      27
# name      3713
# reach       27
# record    1170
# stance       5
# strAcc      85
# strDef      86
# subAvg      94
# tdAcc       83
# tdAvg      529
# tdDef       93
# weight     113
# dtype: int64

# %%
# check for fighter with the same name
df_fighters[df_fighters.duplicated(subset='name', keep=False)]
# Out:
#               DoB  SApM  SLpM  height              name  reach         record  \
# 433   Feb 06 1965  0.40  0.00  5' 11"  Michael McDonald    NaN          1-1-0
# 446   Jan 15 1991  2.76  2.69   5' 9"  Michael McDonald   70.0         17-4-0
# 1308  May 02 1983  3.67  4.00   6' 2"      Tony Johnson   76.0          7-2-0
# 1318           --  4.73  2.00   6' 1"      Tony Johnson    NaN         11-3-0
# 1916  Jul 21 1986  4.46  2.44  5' 10"        Joey Gomez   73.0          6-2-0
# 2092  Aug 29 1989  3.33  3.73  5' 10"        Joey Gomez   71.0          7-1-0
# 2272  Oct 07 1992  6.76  6.24   6' 0"        Mike Davis   72.0          9-2-0
# 2404           --  0.00  0.00      --        Mike Davis    NaN          2-0-0
# 3194  Mar 16 1990  3.23  2.98   5' 4"       Bruno Silva   65.0  12-5-2 (1 NC)
# 3300  Jul 13 1989  0.21  4.00   6' 0"       Bruno Silva   74.0         20-6-0
#
#         stance strAcc strDef  subAvg tdAcc  tdAvg tdDef weight
# 433   Orthodox     0%    50%     0.0    0%   0.00    0%    205
# 446   Orthodox    42%    57%     1.4   66%   1.09   52%    135
# 1308  Orthodox    92%    22%     0.0    0%   0.00   90%    205
# 1318       NaN    53%    31%     0.0   22%   2.00    0%    265
# 1916  Orthodox    28%    55%     0.0  100%   0.62   50%    135
# 2092  Orthodox    49%    50%     0.0   28%   2.00    0%    155
# 2272  Orthodox    53%    57%     0.0   33%   1.39   69%    145
# 2404       NaN     0%     0%     0.0    0%   0.00    0%     --
# 3194  Orthodox    46%    58%     0.0   31%   2.89   64%    125
# 3300  Orthodox    73%     0%     0.0    0%   0.00  100%    185

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### df_fighters cleaning
#
# Quite a lot of preprocessing will need to be done here. First, a few fighters have the same name there. We will add elements to their name to distinguish them. The easiest way would be by adding their weights, since fortunately, the fighters with the same name in our list here have different weight class. We also have 2 Mike Davis, with the 2nd one missing a lot of data. therefore, we will drop him altogether

# %%
# change certain name so that we don't have duplication
df_fighters.iloc[446, 4] = "Michael McDonald 135"
df_fighters.iloc[1318, 4] = "Tony Johnson 265"
df_fighters.iloc[2092, 4] = "Joey Gomez 155"
df_fighters.iloc[3300, 4] = "Bruno Silva 185"
df_fighters.drop([2404], inplace=True)

# %% [markdown]
# We can see that in both of the table, there are a lot of percentages that are in string. We will therefore create a function to convert those to decimal

# %%
def p2d(df, columns):
    for column in columns:
        df[column] = df[column].str.strip('%')
        df[column] = pd.to_numeric(df[column]) / 100

# %%
p2d(df_fighters, ['strAcc', 'strDef', 'tdAcc', 'tdDef'])

# %%
df_fighters.columns
# Out:
# Index(['DoB', 'SApM', 'SLpM', 'height', 'name', 'reach', 'record', 'stance',
#        'strAcc', 'strDef', 'subAvg', 'tdAcc', 'tdAvg', 'tdDef', 'weight'],
#       dtype='object')

# %%
# Some fighters do not have statistics available, and we will remove those fighters.
fighters_clean = df_fighters.loc[~(
                               (df_fighters["strDef"] == 0) &
                               (df_fighters["tdAvg"] == 0) &
                               (df_fighters["tdAcc"] == 0) &
                               (df_fighters["tdDef"] == 0) &
                               (df_fighters["subAvg"] == 0))].copy()

# %%
per_missing_dob = fighters_clean[fighters_clean['DoB'] == '--']['DoB'].count() / len(fighters_clean)
print('the percentage of missing Date of Birth is: {:.2f}'.format(per_missing_dob))
# Out:
# the percentage of missing Date of Birth is: 0.11

# %% [markdown]
# Although the percentage of missing date of birth is quite high, we would remove these fighters anyways since the lack of birth date often mean that the fighter only fought 1 match in UFC, and was quite irrelevant to the sport. Also, it often means that these fighters fought in the very early days of ufc. And as the fan knows, the sport has changed dramatically since then. Including these fighters might add more random noise to our dataset than helping

# %%
fighters_clean = fighters_clean[~(fighters_clean['DoB'] == '--')].copy()

# %%
print("Initially, there are {} fighers in total, after clean up: {} fighers".format(len(df_fighters), len(fighters_clean)))
# Out:
# Initially, there are 3717 fighers in total, after clean up: 2643 fighers

# %%
def get_birth_year(dob):
    return datetime.strptime(dob, '%b %d %Y').year

fighters_clean['born_year'] = fighters_clean['DoB'].apply(lambda x: get_birth_year(x))
fighters_clean.drop(['DoB'], inplace=True, axis=1)

# %%
fighters_clean.set_index('name', inplace=True)

# %%
fighters_clean.head()
# Out:
#                     SApM  SLpM height  reach          record       stance  \
# name
# Justin Frazier      6.11  1.11  6' 0"   75.0          10-3-0     Southpaw
# Gleidson Cutis      8.28  2.99  5' 9"    NaN           7-4-0     Orthodox
# Xavier Foupa-Pokam  2.50  1.47  6' 1"    NaN         32-22-0  Open Stance
# Mirko Filipovic     1.89  2.11  6' 2"   73.0  35-11-2 (1 NC)     Southpaw
# Jordan Johnson      2.64  3.45  6' 2"   79.0          10-0-0     Orthodox
#
#                     strAcc  strDef  subAvg  tdAcc  tdAvg  tdDef weight  \
# name
# Justin Frazier        0.66    0.04     0.0   0.00   0.00   0.00    265
# Gleidson Cutis        0.52    0.59     0.0   0.00   0.00   0.00    155
# Xavier Foupa-Pokam    0.43    0.49     0.0   0.00   0.00   0.16    185
# Mirko Filipovic       0.50    0.63     0.3   0.40   0.19   0.78    230
# Jordan Johnson        0.47    0.53     1.2   0.42   3.25   1.00    205
#
#                     born_year
# name
# Justin Frazier           1989
# Gleidson Cutis           1989
# Xavier Foupa-Pokam       1982
# Mirko Filipovic          1974
# Jordan Johnson           1988

# %% [markdown]
# From my experience, reach is 1 of the most important factor that would determine the strategy and outcome of a fight. yet as we see in the first look of the data, the data is missing for more than a thoudsand of fighters.
#
# The method we will use to move forward is as follow: Reach is often a function of height (although not perfect, this is the closest thing we have from the available data). Therefore, we will try to find another fighter that have the same height as the fighter with missing data and use that fighter height as our value.
# In some cases, we will find multiple fighters with the same height, but different reach. for the sake of simplicity, we will simply get the first non-NaN value

# %%
# fetch first non-NA value of each height
height_ref = fighters_clean.groupby('height')['reach'].median()
height_ref
# Out:
# height
# --        70.0
# 5' 0"     61.0
# 5' 1"     62.0
# 5' 10"    72.0
# 5' 11"    73.0
# 5' 2"     62.0
# 5' 3"     64.0
# 5' 4"     65.0
# 5' 5"     66.0
# 5' 6"     67.0
# 5' 7"     69.0
# 5' 8"     70.0
# 5' 9"     71.0
# 6' 0"     74.0
# 6' 1"     75.0
# 6' 10"     NaN
# 6' 11"    84.0
# 6' 2"     75.0
# 6' 3"     77.0
# 6' 4"     78.5
# 6' 5"     79.0
# 6' 6"     79.0
# 6' 7"     80.0
# 6' 8"     80.0
# 7' 2"      NaN
# 7' 5"      NaN
# Name: reach, dtype: float64

# %%
# apply and check the amount of missing data left
fighters_clean['reach'] = fighters_clean['reach'].fillna(fighters_clean['height'].map(height_ref))
fighters_clean['reach'].isna().sum()
# Out:
# 5

# %%
# with only 5, we can now drop those rows
fighters_clean.dropna(subset=['reach'], inplace=True)
fighters_clean['reach'].isna().sum()
# Out:
# 0

# %%
# stance
fighters_clean['stance'].unique()
# Out:
# array(['Southpaw', 'Orthodox', 'Open Stance', 'Switch', nan, 'Sideways'],
#       dtype=object)

# %%
# we will simply fill the missing stance with Open Stance
fighters_clean['stance'].fillna('Open Stance', inplace=True)

# %%
# convert height from inch to cm
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
# we have some missing data that hide under the form of "--"
fighters_clean[fighters_clean['height'] == '--']
# Out:
#                   SApM  SLpM height  reach  record       stance  strAcc  \
# name
# Amador Ramirez    2.07  4.93     --   70.0   5-4-0  Open Stance    0.51
# Matt Ricehouse    4.80  3.70     --   70.0   6-1-0  Open Stance    0.44
# Logan Nail        2.27  1.93     --   70.0   1-1-0  Open Stance    0.51
# Neal Ewing        1.93  2.27     --   70.0   6-0-0  Open Stance    0.60
# Lee Higgins       3.68  1.02     --   70.0   2-1-0  Open Stance    0.26
# Hiroshi Izumi     2.65  1.95     --   70.0   4-2-0     Orthodox    0.37
# Joe Duarte        4.00  2.27     --   70.0  10-4-0  Open Stance    0.38
# TJ Cook           3.18  2.30     --   70.0  13-5-0  Open Stance    0.47
# Edward Faaloloto  6.25  2.28     --   70.0   2-5-0  Open Stance    0.32
# Maka Watson       1.60  0.93     --   70.0   4-2-0  Open Stance    0.37
# Bryan Travers     3.93  2.33     --   70.0  15-4-0  Open Stance    0.48
#
#                   strDef  subAvg  tdAcc  tdAvg  tdDef weight  born_year
# name
# Amador Ramirez      0.69     0.0   0.33   1.00   0.00    135       1990
# Matt Ricehouse      0.47     0.0   0.22   1.00   0.81    155       1987
# Logan Nail          0.39     0.0   0.00   0.00   0.37    185       1989
# Neal Ewing          0.48     0.0   0.62   5.00   0.00    185       1985
# Lee Higgins         0.40     0.0   0.00   0.00   0.00    155       1980
# Hiroshi Izumi       0.66     0.5   0.70   3.35   1.00    205       1982
# Joe Duarte          0.53     1.0   0.50   3.00   0.69    155       1977
# TJ Cook             0.54     0.0   0.50   1.01   0.00    205       1982
# Edward Faaloloto    0.44     0.0   0.25   1.01   0.33    155       1984
# Maka Watson         0.22     0.0   1.00   2.00   0.33    155       1984
# Bryan Travers       0.55     0.0   0.28   2.00   0.63    155       1983

# %%
# after some research, most of them have a height of 5'7". So we will replace these values in
feet = "5' "
inches = '7"'
height = feet + inches
fighters_clean['height'].replace({"--": height}, inplace=True)

# %%
fighters_clean['height'] = fighters_clean['height'].apply(convert_to_cms)

# %%
# split the record
fighters_clean['record'] = fighters_clean['record'].str.replace(' \(', '-(', regex=True)
fighters_clean[['win', 'lose', 'draw', 'nc']] = fighters_clean['record'].str.split('-', expand=True)

def split_nc(nc):
    return re.findall(r"\d+", nc, re.IGNORECASE)[0]
    
fighters_clean['nc'] = fighters_clean['nc'].apply(lambda x: split_nc(x) if x is not None else 0)
fighters_clean.drop(['record'], axis=1, inplace=True)

fighters_clean.head()
# Out:
#                     SApM  SLpM  height  reach       stance  strAcc  strDef  \
# name
# Justin Frazier      6.11  1.11  182.88   75.0     Southpaw    0.66    0.04
# Gleidson Cutis      8.28  2.99  175.26   71.0     Orthodox    0.52    0.59
# Xavier Foupa-Pokam  2.50  1.47  185.42   75.0  Open Stance    0.43    0.49
# Mirko Filipovic     1.89  2.11  187.96   73.0     Southpaw    0.50    0.63
# Jordan Johnson      2.64  3.45  187.96   79.0     Orthodox    0.47    0.53
#
#                     subAvg  tdAcc  tdAvg  tdDef weight  born_year win lose  \
# name
# Justin Frazier         0.0   0.00   0.00   0.00    265       1989  10    3
# Gleidson Cutis         0.0   0.00   0.00   0.00    155       1989   7    4
# Xavier Foupa-Pokam     0.0   0.00   0.00   0.16    185       1982  32   22
# Mirko Filipovic        0.3   0.40   0.19   0.78    230       1974  35   11
# Jordan Johnson         1.2   0.42   3.25   1.00    205       1988  10    0
#
#                    draw nc
# name
# Justin Frazier        0  0
# Gleidson Cutis        0  0
# Xavier Foupa-Pokam    0  0
# Mirko Filipovic       2  1
# Jordan Johnson        0  0

# %%
# deal with missing weight hiding as '--'
# first check out how many are left
len(fighters_clean[fighters_clean['weight'] == '--'])
# Out:
# 0

# %%
# we can jsut drop them
fighters_clean =  fighters_clean[fighters_clean['weight'] != '--']

# %%
# finally convert the relevant rows from string to int
def string_2_int(df, columns):
    for column in columns:
        df[column] = df[column].astype(int)
        
        
string_2_int(fighters_clean, ['win', 'lose', 'draw', 'nc', 'weight'])

# %%
fighters_clean.dtypes
# Out:
# SApM         float64
# SLpM         float64
# height       float64
# reach        float64
# stance        object
# strAcc       float64
# strDef       float64
# subAvg       float64
# tdAcc        float64
# tdAvg        float64
# tdDef        float64
# weight         int32
# born_year      int64
# win            int32
# lose           int32
# draw           int32
# nc             int32
# dtype: object

# %% [markdown]
# #### df_cards cleaning

# %%
p2d(df_cards, ['f1_sig_strike_per', 'f2_sig_strike_per'])
df_cards
# Out:
#                                  card_name                f1  \
# 0     UFC Fight Night: Santos vs. Teixeira     Gustavo Lopez
# 1          UFC Fight Night: Hall vs. Silva        Jason Witt
# 2          UFC Fight Night: Hall vs. Silva     Dustin Jacoby
# 3          UFC Fight Night: Hall vs. Silva       Miles Johns
# 4            UFC 255: Figueiredo vs. Perez  Sasha Palatnikov
# ...                                    ...               ...
# 6134               UFC 265: Lewis vs. Gane        Manel Kape
# 6135               UFC 265: Lewis vs. Gane     Vince Morales
# 6136               UFC 265: Lewis vs. Gane       Song Yadong
# 6137               UFC 265: Lewis vs. Gane     Vicente Luque
# 6138               UFC 265: Lewis vs. Gane         Jose Aldo
#
#       f1_sig_strike_per  f1_sig_strike_total  f1_td_attempt  f1_td_succeed  \
# 0                  0.60                   43              3              2
# 1                  0.20                    5              0              0
# 2                  0.57                   38              0              0
# 3                  0.45                  105              7              0
# 4                  0.48                  206              9              1
# ...                 ...                  ...            ...            ...
# 6134               0.65                   29              0              0
# 6135               0.38                  196              4              1
# 6136               0.45                  257              3              0
# 6137               0.33                   12              1              1
# 6138               0.51                  223              0              0
#
#                    f2  f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  \
# 0     Anthony Birchak               0.42                   40              0
# 1       Cole Williams               0.64                   31              3
# 2        Justin Ledet               0.32                   31              0
# 3     Kevin Natividad               0.24                  137              1
# 4         Louis Cosce               0.52                  237              1
# ...               ...                ...                  ...            ...
# 6134     Ode Osbourne               0.47                   38              0
# 6135  Drako Rodriguez               0.36                  151              5
# 6136     Casey Kenney               0.41                  190              5
# 6137   Michael Chiesa               0.58                   12              0
# 6138     Pedro Munhoz               0.41                  179              0
#
#       f2_td_succeed        fight_date         fights_location  round_format  \
# 0                 0  November 07 2020  Las Vegas, Nevada, USA             3
# 1                 2   October 31 2020  Las Vegas, Nevada, USA             3
# 2                 0   October 31 2020  Las Vegas, Nevada, USA             3
# 3                 0   October 31 2020  Las Vegas, Nevada, USA             3
# 4                 1  November 21 2020  Las Vegas, Nevada, USA             3
# ...             ...               ...                     ...           ...
# 6134              0    August 07 2021     Houston, Texas, USA             3
# 6135              3    August 07 2021     Houston, Texas, USA             3
# 6136              1    August 07 2021     Houston, Texas, USA             3
# 6137              0    August 07 2021     Houston, Texas, USA             3
# 6138              0    August 07 2021     Houston, Texas, USA             3
#
#       round_fought       weight_class            winner winning_method
# 0                1       Bantamweight     Gustavo Lopez            SUB
# 1                2       Welterweight        Jason Witt            SUB
# 2                1  Light Heavyweight     Dustin Jacoby         KO/TKO
# 3                3       Bantamweight       Miles Johns         KO/TKO
# 4                3       Welterweight  Sasha Palatnikov         KO/TKO
# ...            ...                ...               ...            ...
# 6134             1          Flyweight        Manel Kape         KO/TKO
# 6135             3       Bantamweight     Vince Morales          U-DEC
# 6136             3       Bantamweight       Song Yadong          S-DEC
# 6137             1       Welterweight     Vicente Luque            SUB
# 6138             3       Bantamweight         Jose Aldo          U-DEC
#
# [6139 rows x 18 columns]

# %%
# reuse split birth year function to get year of fight
def get_fight_year(dof):
    return datetime.strptime(dof, '%B %d %Y').year

df_cards['fight_year'] = df_cards['fight_date'].apply(lambda x: get_fight_year(x))
df_cards.drop(['fight_date'], axis=1, inplace=True)

# %%
df_cards
# Out:
#                                  card_name                f1  \
# 0     UFC Fight Night: Santos vs. Teixeira     Gustavo Lopez
# 1          UFC Fight Night: Hall vs. Silva        Jason Witt
# 2          UFC Fight Night: Hall vs. Silva     Dustin Jacoby
# 3          UFC Fight Night: Hall vs. Silva       Miles Johns
# 4            UFC 255: Figueiredo vs. Perez  Sasha Palatnikov
# ...                                    ...               ...
# 6134               UFC 265: Lewis vs. Gane        Manel Kape
# 6135               UFC 265: Lewis vs. Gane     Vince Morales
# 6136               UFC 265: Lewis vs. Gane       Song Yadong
# 6137               UFC 265: Lewis vs. Gane     Vicente Luque
# 6138               UFC 265: Lewis vs. Gane         Jose Aldo
#
#       f1_sig_strike_per  f1_sig_strike_total  f1_td_attempt  f1_td_succeed  \
# 0                  0.60                   43              3              2
# 1                  0.20                    5              0              0
# 2                  0.57                   38              0              0
# 3                  0.45                  105              7              0
# 4                  0.48                  206              9              1
# ...                 ...                  ...            ...            ...
# 6134               0.65                   29              0              0
# 6135               0.38                  196              4              1
# 6136               0.45                  257              3              0
# 6137               0.33                   12              1              1
# 6138               0.51                  223              0              0
#
#                    f2  f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  \
# 0     Anthony Birchak               0.42                   40              0
# 1       Cole Williams               0.64                   31              3
# 2        Justin Ledet               0.32                   31              0
# 3     Kevin Natividad               0.24                  137              1
# 4         Louis Cosce               0.52                  237              1
# ...               ...                ...                  ...            ...
# 6134     Ode Osbourne               0.47                   38              0
# 6135  Drako Rodriguez               0.36                  151              5
# 6136     Casey Kenney               0.41                  190              5
# 6137   Michael Chiesa               0.58                   12              0
# 6138     Pedro Munhoz               0.41                  179              0
#
#       f2_td_succeed         fights_location  round_format  round_fought  \
# 0                 0  Las Vegas, Nevada, USA             3             1
# 1                 2  Las Vegas, Nevada, USA             3             2
# 2                 0  Las Vegas, Nevada, USA             3             1
# 3                 0  Las Vegas, Nevada, USA             3             3
# 4                 1  Las Vegas, Nevada, USA             3             3
# ...             ...                     ...           ...           ...
# 6134              0     Houston, Texas, USA             3             1
# 6135              3     Houston, Texas, USA             3             3
# 6136              1     Houston, Texas, USA             3             3
# 6137              0     Houston, Texas, USA             3             1
# 6138              0     Houston, Texas, USA             3             3
#
#            weight_class            winner winning_method  fight_year
# 0          Bantamweight     Gustavo Lopez            SUB        2020
# 1          Welterweight        Jason Witt            SUB        2020
# 2     Light Heavyweight     Dustin Jacoby         KO/TKO        2020
# 3          Bantamweight       Miles Johns         KO/TKO        2020
# 4          Welterweight  Sasha Palatnikov         KO/TKO        2020
# ...                 ...               ...            ...         ...
# 6134          Flyweight        Manel Kape         KO/TKO        2021
# 6135       Bantamweight     Vince Morales          U-DEC        2021
# 6136       Bantamweight       Song Yadong          S-DEC        2021
# 6137       Welterweight     Vicente Luque            SUB        2021
# 6138       Bantamweight         Jose Aldo          U-DEC        2021
#
# [6139 rows x 18 columns]

# %%
#randomly swap f1 and f2 for half of the dataset so that 50% of f2 are winners
swap_indices = np.random.choice(len(df_cards), size= len(df_cards) //2, replace = False)
df_cards.iloc[swap_indices, [1, 6]] = df_cards.iloc[swap_indices, [6, 1]].values

# %%
# quick check
df_cards["winner"] = df_cards["winner"] == df_cards["f1"]
df_cards["winner"] = df_cards["winner"].astype(int)
df_cards["winner"].value_counts()
# Out:
# 1    3070
# 0    3069
# Name: winner, dtype: int64

# %%
# we had to change some names earlier due to duplication, we will do the same here
cards_clean = df_cards.copy()
for col in ['f1', 'f2']:
    cards_clean.loc[(cards_clean[col] == 'Michael McDonald') & 
                    (cards_clean['weight_class'] == 'Bantamweight'), col] = "Michael McDonald 135"
    
    cards_clean.loc[(cards_clean[col] == 'Tony Johnson') & 
                    (cards_clean['weight_class'] == 'Heavyweight'), col] = "Tony Johnson 265"
    
    cards_clean.loc[(cards_clean[col] == 'Joey Gomez') & 
                    (cards_clean['weight_class'] == 'Welterweight'), col] = "Joey Gomez 155"
    
    cards_clean.loc[(cards_clean[col] == 'Bruno Silva') & 
                    (cards_clean['weight_class'] == 'Light Heavyweight'), col] = "Bruno Silva 185"

# %%
cards_clean
# Out:
#                                  card_name              f1  f1_sig_strike_per  \
# 0     UFC Fight Night: Santos vs. Teixeira   Gustavo Lopez               0.60
# 1          UFC Fight Night: Hall vs. Silva      Jason Witt               0.20
# 2          UFC Fight Night: Hall vs. Silva    Justin Ledet               0.57
# 3          UFC Fight Night: Hall vs. Silva     Miles Johns               0.45
# 4            UFC 255: Figueiredo vs. Perez     Louis Cosce               0.48
# ...                                    ...             ...                ...
# 6134               UFC 265: Lewis vs. Gane    Ode Osbourne               0.65
# 6135               UFC 265: Lewis vs. Gane   Vince Morales               0.38
# 6136               UFC 265: Lewis vs. Gane    Casey Kenney               0.45
# 6137               UFC 265: Lewis vs. Gane  Michael Chiesa               0.33
# 6138               UFC 265: Lewis vs. Gane    Pedro Munhoz               0.51
#
#       f1_sig_strike_total  f1_td_attempt  f1_td_succeed                f2  \
# 0                      43              3              2   Anthony Birchak
# 1                       5              0              0     Cole Williams
# 2                      38              0              0     Dustin Jacoby
# 3                     105              7              0   Kevin Natividad
# 4                     206              9              1  Sasha Palatnikov
# ...                   ...            ...            ...               ...
# 6134                   29              0              0        Manel Kape
# 6135                  196              4              1   Drako Rodriguez
# 6136                  257              3              0       Song Yadong
# 6137                   12              1              1     Vicente Luque
# 6138                  223              0              0         Jose Aldo
#
#       f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  f2_td_succeed  \
# 0                  0.42                   40              0              0
# 1                  0.64                   31              3              2
# 2                  0.32                   31              0              0
# 3                  0.24                  137              1              0
# 4                  0.52                  237              1              1
# ...                 ...                  ...            ...            ...
# 6134               0.47                   38              0              0
# 6135               0.36                  151              5              3
# 6136               0.41                  190              5              1
# 6137               0.58                   12              0              0
# 6138               0.41                  179              0              0
#
#              fights_location  round_format  round_fought       weight_class  \
# 0     Las Vegas, Nevada, USA             3             1       Bantamweight
# 1     Las Vegas, Nevada, USA             3             2       Welterweight
# 2     Las Vegas, Nevada, USA             3             1  Light Heavyweight
# 3     Las Vegas, Nevada, USA             3             3       Bantamweight
# 4     Las Vegas, Nevada, USA             3             3       Welterweight
# ...                      ...           ...           ...                ...
# 6134     Houston, Texas, USA             3             1          Flyweight
# 6135     Houston, Texas, USA             3             3       Bantamweight
# 6136     Houston, Texas, USA             3             3       Bantamweight
# 6137     Houston, Texas, USA             3             1       Welterweight
# 6138     Houston, Texas, USA             3             3       Bantamweight
#
#       winner winning_method  fight_year
# 0          1            SUB        2020
# 1          1            SUB        2020
# 2          0         KO/TKO        2020
# 3          1         KO/TKO        2020
# 4          0         KO/TKO        2020
# ...      ...            ...         ...
# 6134       0         KO/TKO        2021
# 6135       1          U-DEC        2021
# 6136       0          S-DEC        2021
# 6137       0            SUB        2021
# 6138       0          U-DEC        2021
#
# [6139 rows x 18 columns]

# %%
all_fighters = fighters_clean.index.tolist()
all_fighters[:10]
# Out:
# ['Justin Frazier',
#  'Gleidson Cutis',
#  'Xavier Foupa-Pokam',
#  'Mirko Filipovic',
#  'Jordan Johnson',
#  'Martin Kampmann',
#  'Darren Elkins',
#  'Austen Lane',
#  'Rachael Ostovich',
#  'Travis Lutter']

# %%
# drop the fights that don't have the figther in the fighters_clean df
cards_clean = cards_clean.loc[(cards_clean["f1"].isin(all_fighters)) &
                              (cards_clean["f2"].isin(all_fighters))]
cards_clean.reset_index(inplace=True, drop=True)

# %%
cards_clean.head()
# Out:
#                               card_name             f1  f1_sig_strike_per  \
# 0  UFC Fight Night: Santos vs. Teixeira  Gustavo Lopez               0.60
# 1       UFC Fight Night: Hall vs. Silva     Jason Witt               0.20
# 2       UFC Fight Night: Hall vs. Silva   Justin Ledet               0.57
# 3       UFC Fight Night: Hall vs. Silva    Miles Johns               0.45
# 4         UFC 255: Figueiredo vs. Perez    Louis Cosce               0.48
#
#    f1_sig_strike_total  f1_td_attempt  f1_td_succeed                f2  \
# 0                   43              3              2   Anthony Birchak
# 1                    5              0              0     Cole Williams
# 2                   38              0              0     Dustin Jacoby
# 3                  105              7              0   Kevin Natividad
# 4                  206              9              1  Sasha Palatnikov
#
#    f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  f2_td_succeed  \
# 0               0.42                   40              0              0
# 1               0.64                   31              3              2
# 2               0.32                   31              0              0
# 3               0.24                  137              1              0
# 4               0.52                  237              1              1
#
#           fights_location  round_format  round_fought       weight_class  \
# 0  Las Vegas, Nevada, USA             3             1       Bantamweight
# 1  Las Vegas, Nevada, USA             3             2       Welterweight
# 2  Las Vegas, Nevada, USA             3             1  Light Heavyweight
# 3  Las Vegas, Nevada, USA             3             3       Bantamweight
# 4  Las Vegas, Nevada, USA             3             3       Welterweight
#
#    winner winning_method  fight_year
# 0       1            SUB        2020
# 1       1            SUB        2020
# 2       0         KO/TKO        2020
# 3       1         KO/TKO        2020
# 4       0         KO/TKO        2020

# %%
print("we had {} cards initially. After clean up: {} cards".format(len(df_cards), len(cards_clean)))
# Out:
# we had 6139 cards initially. After clean up: 5948 cards

# %%
# get data of fighter 1 and fighter 2
f1_data = fighters_clean.loc[cards_clean['f1']]
f1_data = f1_data.add_suffix('_f1')
f2_data = fighters_clean.loc[cards_clean['f2']]
f2_data = f2_data.add_suffix('_f2')

# %%
f1_data.head()
# Out:
#                SApM_f1  SLpM_f1  height_f1  reach_f1 stance_f1  strAcc_f1  \
# name
# Gustavo Lopez     4.65     2.24     165.10      67.0  Orthodox       0.41
# Jason Witt        3.10     2.63     177.80      70.0  Orthodox       0.49
# Justin Ledet      4.82     3.35     193.04      80.0  Orthodox       0.39
# Miles Johns       2.50     4.03     170.18      66.0  Orthodox       0.53
# Louis Cosce       9.30     8.22     175.26      71.0  Orthodox       0.48
#
#                strDef_f1  subAvg_f1  tdAcc_f1  tdAvg_f1  tdDef_f1  weight_f1  \
# name
# Gustavo Lopez       0.51        0.5      0.50      1.07      0.27        135
# Jason Witt          0.50        1.3      0.45      6.46      1.00        170
# Justin Ledet        0.49        0.2      0.50      0.23      0.42        205
# Miles Johns         0.71        0.0      0.30      0.99      0.92        135
# Louis Cosce         0.48        0.0      0.11      1.07      0.00        170
#
#                born_year_f1  win_f1  lose_f1  draw_f1  nc_f1
# name
# Gustavo Lopez          1989      12        6        0      0
# Jason Witt             1986      19        7        0      0
# Justin Ledet           1988       9        4        0      1
# Miles Johns            1994      12        1        0      0
# Louis Cosce            1995       7        1        0      0

# %%
f2_data.head()
# Out:
#                   SApM_f2  SLpM_f2  height_f2  reach_f2 stance_f2  strAcc_f2  \
# name
# Anthony Birchak      3.67     3.93     172.72      69.0  Orthodox       0.36
# Cole Williams        5.34     0.31     182.88      73.0  Orthodox       0.27
# Dustin Jacoby        3.36     4.32     190.50      76.0  Orthodox       0.49
# Kevin Natividad      4.02     2.63     167.64      70.0  Orthodox       0.24
# Sasha Palatnikov     5.44     6.69     185.42      72.0    Switch       0.53
#
#                   strDef_f2  subAvg_f2  tdAcc_f2  tdAvg_f2  tdDef_f2  \
# name
# Anthony Birchak        0.56        0.5      0.14      0.48      0.61
# Cole Williams          0.23        0.0      0.00      0.00      0.25
# Dustin Jacoby          0.58        0.0      0.40      0.35      0.58
# Kevin Natividad        0.54        0.0      0.00      0.00      1.00
# Sasha Palatnikov       0.52        0.0      1.00      0.72      0.70
#
#                   weight_f2  born_year_f2  win_f2  lose_f2  draw_f2  nc_f2
# name
# Anthony Birchak         135          1986      16        8        0      0
# Cole Williams           170          1983      11        3        0      0
# Dustin Jacoby           205          1988      15        5        1      0
# Kevin Natividad         145          1993       9        3        0      0
# Sasha Palatnikov        170          1989       6        4        0      0

# %%
# join the 2 dataframe
f1_data.reset_index(inplace=True, drop=True)
f2_data.reset_index(inplace=True, drop=True)
final_df = pd.concat([cards_clean, f1_data, f2_data], axis=1, sort=False)

# %%
final_df['f1_age_when_fight'] = final_df['fight_year'] - final_df['born_year_f1']
final_df['f2_age_when_fight'] = final_df['fight_year'] - final_df['born_year_f2']

# %%
final_df.head()
# Out:
#                               card_name             f1  f1_sig_strike_per  \
# 0  UFC Fight Night: Santos vs. Teixeira  Gustavo Lopez               0.60
# 1       UFC Fight Night: Hall vs. Silva     Jason Witt               0.20
# 2       UFC Fight Night: Hall vs. Silva   Justin Ledet               0.57
# 3       UFC Fight Night: Hall vs. Silva    Miles Johns               0.45
# 4         UFC 255: Figueiredo vs. Perez    Louis Cosce               0.48
#
#    f1_sig_strike_total  f1_td_attempt  f1_td_succeed                f2  \
# 0                   43              3              2   Anthony Birchak
# 1                    5              0              0     Cole Williams
# 2                   38              0              0     Dustin Jacoby
# 3                  105              7              0   Kevin Natividad
# 4                  206              9              1  Sasha Palatnikov
#
#    f2_sig_strike_per  f2_sig_strike_total  f2_td_attempt  ...  tdAvg_f2  \
# 0               0.42                   40              0  ...      0.48
# 1               0.64                   31              3  ...      0.00
# 2               0.32                   31              0  ...      0.35
# 3               0.24                  137              1  ...      0.00
# 4               0.52                  237              1  ...      0.72
#
#   tdDef_f2  weight_f2  born_year_f2 win_f2  lose_f2 draw_f2  nc_f2  \
# 0     0.61        135          1986     16        8       0      0
# 1     0.25        170          1983     11        3       0      0
# 2     0.58        205          1988     15        5       1      0
# 3     1.00        145          1993      9        3       0      0
# 4     0.70        170          1989      6        4       0      0
#
#    f1_age_when_fight  f2_age_when_fight
# 0                 31                 34
# 1                 34                 37
# 2                 32                 32
# 3                 26                 27
# 4                 25                 31
#
# [5 rows x 54 columns]

# %%
# last checks
print(final_df.isna().sum())
print(final_df.dtypes)
# Out:
# card_name              0
# f1                     0
# f1_sig_strike_per      0
# f1_sig_strike_total    0
# f1_td_attempt          0
# f1_td_succeed          0
# f2                     0
# f2_sig_strike_per      0
# f2_sig_strike_total    0
# f2_td_attempt          0
# f2_td_succeed          0
# fights_location        0
# round_format           0
# round_fought           0
# weight_class           0
# winner                 0
# winning_method         0
# fight_year             0
# SApM_f1                0
# SLpM_f1                0
# height_f1              0
# reach_f1               0
# stance_f1              0
# strAcc_f1              0
# strDef_f1              0
# subAvg_f1              0
# tdAcc_f1               0
# tdAvg_f1               0
# tdDef_f1               0
# weight_f1              0
# born_year_f1           0
# win_f1                 0
# lose_f1                0
# draw_f1                0
# nc_f1                  0
# SApM_f2                0
# SLpM_f2                0
# height_f2              0
# reach_f2               0
# stance_f2              0
# strAcc_f2              0
# strDef_f2              0
# subAvg_f2              0
# tdAcc_f2               0
# tdAvg_f2               0
# tdDef_f2               0
# weight_f2              0
# born_year_f2           0
# win_f2                 0
# lose_f2                0
# draw_f2                0
# nc_f2                  0
# f1_age_when_fight      0
# f2_age_when_fight      0
# dtype: int64
# card_name               object
# f1                      object
# f1_sig_strike_per      float64
# f1_sig_strike_total      int64
# f1_td_attempt            int64
# f1_td_succeed            int64
# f2                      object
# f2_sig_strike_per      float64
# f2_sig_strike_total      int64
# f2_td_attempt            int64
# f2_td_succeed            int64
# fights_location         object
# round_format             int64
# round_fought             int64
# weight_class            object
# winner                   int32
# winning_method          object
# fight_year               int64
# SApM_f1                float64
# SLpM_f1                float64
# height_f1              float64
# reach_f1               float64
# stance_f1               object
# strAcc_f1              float64
# strDef_f1              float64
# subAvg_f1              float64
# tdAcc_f1               float64
# tdAvg_f1               float64
# tdDef_f1               float64
# weight_f1                int32
# born_year_f1             int64
# win_f1                   int32
# lose_f1                  int32
# draw_f1                  int32
# nc_f1                    int32
# SApM_f2                float64
# SLpM_f2                float64
# height_f2              float64
# reach_f2               float64
# stance_f2               object
# strAcc_f2              float64
# strDef_f2              float64
# subAvg_f2              float64
# tdAcc_f2               float64
# tdAvg_f2               float64
# tdDef_f2               float64
# weight_f2                int32
# born_year_f2             int64
# win_f2                   int32
# lose_f2                  int32
# draw_f2                  int32
# nc_f2                    int32
# f1_age_when_fight        int64
# f2_age_when_fight        int64
# dtype: object

# %%
final_df.to_csv('cleaned_dataset.csv', index=False)
